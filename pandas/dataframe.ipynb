# %%
import numpy as np
import pandas as pd

# %%
#creating a data frame

# %%
data = {
    "name" : ["Aryan","Rohit","Virat","Hardik"],
    "age" : [20,36,37,30],
    "city":["Haryana","Mumbai",'Delhi','Gujrat']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age     city
# 0   Aryan   20  Haryana
# 1   Rohit   36   Mumbai
# 2   Virat   37    Delhi
# 3  Hardik   30   Gujrat

# %%
data_list = [
     ["Aryan",20,'haryana'],
     ['virat',36,'Delhi'],
     ["rohit",37,'Mumbia']
]
df2=pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1        2
# 0  Aryan  20  haryana
# 1  virat  36    Delhi
# 2  rohit  37   Mumbia

# %%
columns = ["name",'age','place']
pd3 = pd.DataFrame(data_list,columns=columns)

# %%
pd3
# Out:
#     name  age    place
# 0  Aryan   20  haryana
# 1  virat   36    Delhi
# 2  rohit   37   Mumbia

# %%
# selection and indexing of columns

# %%
df
# Out:
#      name  age     city
# 0   Aryan   20  Haryana
# 1   Rohit   36   Mumbai
# 2   Virat   37    Delhi
# 3  Hardik   30   Gujrat

# %%
df['name']
# Out:
# 0     Aryan
# 1     Rohit
# 2     Virat
# 3    Hardik
# Name: name, dtype: object

# %%
df[['name','age']]
# Out:
#      name  age
# 0   Aryan   20
# 1   Rohit   36
# 2   Virat   37
# 3  Hardik   30

# %%
#creating a column

# %%
df["salary"] = [7000000,2000000,1000000,5000000]

# %%
df
# Out:
#      name  age     city   salary
# 0   Aryan   20  Haryana  7000000
# 1   Rohit   36   Mumbai  2000000
# 2   Virat   37    Delhi  1000000
# 3  Hardik   30   Gujrat  5000000

# %%
#removing a column

# %%
df.drop('salary',axis = 1)  #it only show the deleted data but main data is not remove from data it is stored in memory
# Out:
#      name  age     city
# 0   Aryan   20  Haryana
# 1   Rohit   36   Mumbai
# 2   Virat   37    Delhi
# 3  Hardik   30   Gujrat

# %%
df  #here it can see data is still present
# Out:
#      name  age     city   salary
# 0   Aryan   20  Haryana  7000000
# 1   Rohit   36   Mumbai  2000000
# 2   Virat   37    Delhi  1000000
# 3  Hardik   30   Gujrat  5000000

# %%
df.drop(1,axis = 0)   #rows data delete
# Out:
#      name  age     city   salary
# 0   Aryan   20  Haryana  7000000
# 2   Virat   37    Delhi  1000000
# 3  Hardik   30   Gujrat  5000000

# %%
df
# Out:
#      name  age     city   salary
# 0   Aryan   20  Haryana  7000000
# 1   Rohit   36   Mumbai  2000000
# 2   Virat   37    Delhi  1000000
# 3  Hardik   30   Gujrat  5000000

# %%
df.drop('salary',axis=1,inplace=True)   #by using it  inplace=True  its delete data in memory anda cann't be retrieve

# %%
df
# Out:
#      name  age     city
# 0   Aryan   20  Haryana
# 1   Rohit   36   Mumbai
# 2   Virat   37    Delhi
# 3  Hardik   30   Gujrat

# %%
#selecting rows

# %%
df
# Out:
#      name  age     city
# 0   Aryan   20  Haryana
# 1   Rohit   36   Mumbai
# 2   Virat   37    Delhi
# 3  Hardik   30   Gujrat

# %%
df.loc[[0]]
# Out:
#     name  age     city
# 0  Aryan   20  Haryana

# %%
df.iloc[[1]]  //i means index location
# Out:
#     name  age    city
# 1  Rohit   36  Mumbai

# %%
df.loc[[0,1]]
# Out:
#     name  age     city
# 0  Aryan   20  Haryana
# 1  Rohit   36   Mumbai

# %%
#selecting Subsets Of Row And Column

# %%
df.loc[[0,1]][['age','city']]
# Out:
#    age     city
# 0   20  Haryana
# 1   36   Mumbai

# %%
df.loc[[1,2]][['name','age']]
# Out:
#     name  age
# 1  Rohit   36
# 2  Virat   37

# %%
#conditional statement

# %%
df
# Out:
#      name  age     city
# 0   Aryan   20  Haryana
# 1   Rohit   36   Mumbai
# 2   Virat   37    Delhi
# 3  Hardik   30   Gujrat

# %%
df[df['age']>30]
# Out:
#     name  age    city
# 1  Rohit   36  Mumbai
# 2  Virat   37   Delhi

# %%
df[(df['age']>30) & (df['city']=='Delhi')]
# Out:
#     name  age   city
# 2  Virat   37  Delhi
